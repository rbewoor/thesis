# %%
## to list files in a folder of google drive

# %%
from __future__ import print_function

import pickle
import os
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import argparse
import sys
import datetime
import time

# %%
def setup_drive_service():
    try:
        # If modifying these scopes, delete the file token.pickle.
        SCOPES = ['https://www.googleapis.com/auth/drive']

        creds = None
        gdrive_creds_json_loc = r'/home/rohit/PyWDUbuntu/thesis/gdrive_pil_20200701/credentials_pil_thesis_work_oauth_client_id_20200916.json'

        CREDS_PICKLE_TOP_FOLDER = r'/home/rohit/PyWDUbuntu/thesis/gdrive_pil_20200701/'
        creds_pickle_file_loc = r'/home/rohit/PyWDUbuntu/thesis/gdrive_pil_20200701/token_pil_thesis_work_oauth_client_id_20200916.pickle'
        # The file token.pickle stores the user's access and refresh tokens, and is
        # created automatically when the authorization flow completes for the first
        # time.
        if os.path.exists(creds_pickle_file_loc):
            with open(creds_pickle_file_loc, 'rb') as token:
                creds = pickle.load(token)
        # If there are no (valid) credentials available, let the user log in.
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                creds.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(
                    gdrive_creds_json_loc, SCOPES)
                creds = flow.run_local_server(port=0)
            # Save the credentials for the next run
            with open(creds_pickle_file_loc, 'wb') as token:
                pickle.dump(creds, token)

        drive_serviceservice = build('drive', 'v3', credentials=creds)
        print(f"\n\ntype of drive_serviceservice should say    <class 'googleapiclient.discovery.Resource'> =\n{type(drive_serviceservice)}\n\n")
        
        return drive_serviceservice
    except:
        return None

# %%
def list_files_in_gdrive_overall(_service):
    ## NOTE: To restrict the search to folders, use the query string to set the MIME type to 
    ##       q: mimeType = 'application/vnd.google-apps.folder'
    MAX_PAGES_LIMIT = 2
    count_pages = 0
    count_files = 0
    page_token = None
    while True:
        response = _service.files().list(q="mimeType='image/jpeg'",
                                              spaces='drive',
                                              fields='nextPageToken, files(id, name)',
                                              pageToken=page_token).execute()
        print(f"\nFiles for PAGE{count_pages+1}:\n")
        for file in response.get('files', []):
            # Process change
            print(f"Found file: {( file.get('name'), file.get('id') )}")
            count_files += 1
        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break
        count_pages += 1
        if count_pages > MAX_PAGES_LIMIT:
            print(f"\n\nNumber of files found = {count_files}\n\n")
            print(f"\n\nMaximum page limit reached {MAX_PAGES_LIMIT} and breaking\n\n")
            break

# %%
def list_folders_in_gdrive_overall(_service):
    ## NOTE: To restrict the search to folders, use the query string to set the MIME type to 
    ##       q: mimeType = 'application/vnd.google-apps.folder'
    MAX_PAGES_LIMIT = 10
    count_pages = 0
    count_folders = 0
    page_token = None
    while True:
        response = _service.files().list(q="mimeType='application/vnd.google-apps.folder'",
                                              spaces='drive',
                                              fields='nextPageToken, files(id, name)',
                                              pageToken=page_token).execute()
        print(f"\nFolders for PAGE {count_pages+1}:\n")
        for file in response.get('files', []):
            # Process change
            print(f"Found folder: {( file.get('name'), file.get('id') )}")
            count_folders += 1
        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break
        count_pages += 1
        if count_pages > MAX_PAGES_LIMIT:
            print(f"\n\nNumber of folders found = {count_folder}\n\n")
            print(f"\n\nMaximum page limit reached {MAX_PAGES_LIMIT} and breaking\n\n")
            break

# %%
def list_items_in_gdrive_target_folder(_service, _folder_id, _files_or_folders = 'both'):
    ## NOTE: To restrict the search to folders, use the query string to set the MIME type to 
    ##       q: mimeType = 'application/vnd.google-apps.folder'
    MAX_PAGES_LIMIT = 5
    count_pages = 0
    count_files = 0
    page_token = None
    if _files_or_folders == 'folders':
        query_only_folders = "'" + _folder_id + "'" + ' in parents'+ ' and ' + "mimeType='application/vnd.google-apps.folder'"
        query = query_only_folders
    elif _files_or_folders == 'files':
        query_only_files = "'" + _folder_id + "'" + ' in parents'+ ' and ' + "mimeType != 'application/vnd.google-apps.folder'"
        query = query_only_files
    elif _files_or_folders == 'both': ## should be defaut is both
        query_folders_and_files = "'" + _folder_id + "'" + ' in parents'
        query = query_folders_and_files
    else: ## invalid value sent
        print(f"\n\nERROR : invalid value for the '_files_or_folders' parameter. Expected one of these three options:")
        print(f"both     OR    files    OR    folders")
        print(f"Your query parater=\n{_files_or_folders}\n")
        return None
    print(f"\nQuery parameter built as:{query}\n")
    while True:
        #response = _service.files().list(q="'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents",
        #                                      spaces='drive',
        #                                      fields='nextPageToken, files(id, name)',
        #                                      pageToken=page_token).execute()
        response = _service.files().list(q=query,
                                      spaces='drive',
                                      fields='nextPageToken, files(id, name)',
                                      pageToken=page_token).execute()
        print(f"\nItems for PAGE {count_pages+1}:\n")
        for file in response.get('files', []):
            # Process change
            print(f"Found folder/file: {( file.get('name'), file.get('id') )}")
            count_files += 1
        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break
        count_pages += 1
        if count_pages > MAX_PAGES_LIMIT:
            print(f"\n\nNumber of itmes found = {count_files}\n\n")
            print(f"\n\nMaximum page limit reached {MAX_PAGES_LIMIT} and breaking\n\n")
            break

# %%
def retrieve_items_in_gdrive_target_folder(_service, _folder_id, _files_or_folders = 'both', _MAX_PAGES_LIMIT = 3):
    ## NOTE: To restrict the search to folders, use the query string to set the MIME type to 
    ##       q: mimeType = 'application/vnd.google-apps.folder'
    MAX_PAGES_LIMIT = _MAX_PAGES_LIMIT
    count_pages = 0
    count_files = 0
    page_token = None
    if _files_or_folders == 'folders':
        query_only_folders = "'" + _folder_id + "'" + ' in parents'+ ' and ' + "mimeType='application/vnd.google-apps.folder'"
        query = query_only_folders
    elif _files_or_folders == 'files':
        query_only_files = "'" + _folder_id + "'" + ' in parents'+ ' and ' + "mimeType != 'application/vnd.google-apps.folder'"
        query = query_only_files
    elif _files_or_folders == 'both': ## should be defaut is both
        query_folders_and_files = "'" + _folder_id + "'" + ' in parents'
        query = query_folders_and_files
    else: ## invalid value sent
        print(f"\n\nERROR : invalid value for the '_files_or_folders' parameter. Expected one of these three options:")
        print(f"both     OR    files    OR    folders")
        print(f"Your query parater=\n{_files_or_folders}\n")
        return None
    print(f"\nQuery parameter built as:{query}\n")
    items_result = []
    while True:
        #response = _service.files().list(q="'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents",
        #                                      spaces='drive',
        #                                      fields='nextPageToken, files(id, name)',
        #                                      pageToken=page_token).execute()
        response = _service.files().list(q=query,
                                      spaces='drive',
                                      fields='nextPageToken, files(id, name)',
                                      pageToken=page_token).execute()
        #print(f"\nItems for PAGE {count_pages+1}:\n")
        for file in response.get('files', []):
            # Process change
            #print(f"Found folder/file: {( file.get('name'), file.get('id') )}")
            items_result.append( {'name': file.get('name') , 'id': file.get('id')} )
            count_files += 1
        page_token = response.get('nextPageToken', None)
        if page_token is None:
            break
        count_pages += 1
        if count_pages > MAX_PAGES_LIMIT:
            print(f"\n\nNumber of itmes found = {count_files}\n\n")
            print(f"\n\nMaximum page limit reached {MAX_PAGES_LIMIT} and breaking\n\n")
            break
    return items_result

# %%
def delete_file_items(_service, _file_id_arr, _status_freq = 100):
    count_files = len(_file_id_arr)
    count_deleted , count_problem = 0, 0
    problem_files = []
    #print(f"{_file_id_arr}")
    print(f"\n\nInput array has {count_files} files to delete")
    
    for idx, finfo_d in enumerate(_file_id_arr):
        #print(f"\nFile {idx+1} : {finfo_d.get('name')}")
        if idx % _status_freq == 0:
            print(f"At {datetime.datetime.now().strftime('%H:%M:%S')} :: idx = {idx+1} , Total = {count_files} , Deleted = {count_deleted} , Problem = {count_problem}")
        try:
            response = _service.files().delete(fileId=finfo_d.get('id'),
                                                              supportsAllDrives='False').execute()
            count_deleted += 1
        except Exception as e:
            problem_files.append(finfo_d)
            print(f"Exception =\n{e}")
            count_problem += 1
    print(f"\n\nSummary :: Total = {count_files} , Deleted = {count_deleted} , Problem = {count_problem}")
    return problem_files, count_files, count_deleted, count_problem

# %%
## make the service
service = setup_drive_service()
if service is None:
    print(f"\n\nFATAL ERROR: Could not setup gdrive service\n\n")
else:

    print(f"\n\nService setup SUCCESS\n\n")
# Out:
# type of drive_serviceservice should say    <class 'googleapiclient.discovery.Resource'> =
# <class 'googleapiclient.discovery.Resource'>
#
#
#
#
# Service setup SUCCESS

# %%
## my funcs
#list_files_in_gdrive_overall  -- display the info, does not return
#list_folders_in_gdrive_overall  -- display the info, does not return

## -- use the target folder querying functions  1) only files, 2) only folders 3) both (default)
#list_items_in_gdrive_target_folder  -- display the info, does not return
#retrieve_items_in_gdrive_target_folder  -- return the info , do not display

#delete_file_items  --  send an array of dict info (filename and id) to delete all those files

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 50
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")

# %% [markdown]
# ## DELETE RUN 5 - RETRIEVED WITH MAX PAGES LIMIT = 100

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv'  ## coco_train2017_118k  folder


MAX_PAGES_LIMIT = 200
files_to_delete_arr = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files', _MAX_PAGES_LIMIT = MAX_PAGES_LIMIT)
print(f"\nFew Results for query with FILES=\n{files_to_delete_arr[:10]}")

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 125
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")

# %% [markdown]
# ## DELETE RUN 4 - RETRIEVED WITH MAX PAGES LIMIT = 100

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv'  ## coco_train2017_118k  folder


MAX_PAGES_LIMIT = 150
files_to_delete_arr = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files', _MAX_PAGES_LIMIT = MAX_PAGES_LIMIT)
print(f"\nFew Results for query with FILES=\n{files_to_delete_arr[:10]}")
# Out:
# Query parameter built as:'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
#
# Number of itmes found = 15100
#
#
#
#
# Maximum page limit reached 150 and breaking
#
#
#
# Few Results for query with FILES=
# [{'name': '000000206731.jpg', 'id': '1XjZcf-JzqFU24K-33FeK68V-yabhAAsk'}, {'name': '000000498265.jpg', 'id': '1l1lQpGxGpBCyXuR3pOcF6gJGyXZ1Sid3'}, {'name': '000000361381.jpg', 'id': '1ToC2DyxYrGtOvsJTYAl-WSL2ewADamwE'}, {'name': '000000458208.jpg', 'id': '15czg6a7IWpOH7UfgUSFptK1b0g-b1Sep'}, {'name': '000000398260.jpg', 'id': '17keFJ8o8hezHAW205h49kSKCb9ilGkT3'}, {'name': '000000068752.jpg', 'id': '1abZm-NcY_s53pvKTtEEszvY1q83G5zna'}, {'name': '000000303126.jpg', 'id': '1dQwn-sbHBPcJ4d-m6abIhHbXg8_dWPF7'}, {'name': '000000523718.jpg', 'id': '19tDIxqmMz5WNfaYhWNw9aC8ZQfAjH0Jk'}, {'name': '000000399499.jpg', 'id': '1ltqMTK69kYCOijE0ymwhaJLQ0RT5bzS5'}, {'name': '000000000491.jpg', 'id': '1HDHQjACiOg7x5MtQiaj6qJyu7DZthtaC'}]

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 75
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")
# Out:
# Input array has 15100 files to delete
# At 19:35:02 :: idx = 1 , Total = 15100 , Deleted = 0 , Problem = 0
# At 19:35:59 :: idx = 76 , Total = 15100 , Deleted = 75 , Problem = 0
# At 19:36:51 :: idx = 151 , Total = 15100 , Deleted = 150 , Problem = 0
# At 19:37:38 :: idx = 226 , Total = 15100 , Deleted = 225 , Problem = 0
# At 19:38:27 :: idx = 301 , Total = 15100 , Deleted = 300 , Problem = 0
# At 19:39:21 :: idx = 376 , Total = 15100 , Deleted = 375 , Problem = 0
# At 19:40:06 :: idx = 451 , Total = 15100 , Deleted = 450 , Problem = 0
# At 19:40:52 :: idx = 526 , Total = 15100 , Deleted = 525 , Problem = 0
# At 19:41:39 :: idx = 601 , Total = 15100 , Deleted = 600 , Problem = 0
# At 19:42:26 :: idx = 676 , Total = 15100 , Deleted = 675 , Problem = 0
# At 19:43:15 :: idx = 751 , Total = 15100 , Deleted = 750 , Problem = 0
# At 19:44:06 :: idx = 826 , Total = 15100 , Deleted = 825 , Problem = 0
# At 19:45:01 :: idx = 901 , Total = 15100 , Deleted = 900 , Problem = 0
# At 19:45:49 :: idx = 976 , Total = 15100 , Deleted = 975 , Problem = 0
# At 19:46:36 :: idx = 1051 , Total = 15100 , Deleted = 1050 , Problem = 0
# At 19:47:25 :: idx = 1126 , Total = 15100 , Deleted = 1125 , Problem = 0
# At 19:48:12 :: idx = 1201 , Total = 15100 , Deleted = 1200 , Problem = 0
# At 19:49:03 :: idx = 1276 , Total = 15100 , Deleted = 1275 , Problem = 0
# At 19:49:51 :: idx = 1351 , Total = 15100 , Deleted = 1350 , Problem = 0
# At 19:50:39 :: idx = 1426 , Total = 15100 , Deleted = 1425 , Problem = 0
# At 19:51:26 :: idx = 1501 , Total = 15100 , Deleted = 1500 , Problem = 0
# At 19:52:14 :: idx = 1576 , Total = 15100 , Deleted = 1575 , Problem = 0
# At 19:53:03 :: idx = 1651 , Total = 15100 , Deleted = 1650 , Problem = 0
# At 19:53:53 :: idx = 1726 , Total = 15100 , Deleted = 1725 , Problem = 0
# At 19:54:36 :: idx = 1801 , Total = 15100 , Deleted = 1800 , Problem = 0
# At 19:55:18 :: idx = 1876 , Total = 15100 , Deleted = 1875 , Problem = 0
# At 19:55:59 :: idx = 1951 , Total = 15100 , Deleted = 1950 , Problem = 0
# At 19:56:41 :: idx = 2026 , Total = 15100 , Deleted = 2025 , Problem = 0
# At 19:57:25 :: idx = 2101 , Total = 15100 , Deleted = 2100 , Problem = 0
# At 19:58:08 :: idx = 2176 , Total = 15100 , Deleted = 2175 , Problem = 0
# At 19:59:00 :: idx = 2251 , Total = 15100 , Deleted = 2250 , Problem = 0
# At 19:59:45 :: idx = 2326 , Total = 15100 , Deleted = 2325 , Problem = 0
# At 20:00:28 :: idx = 2401 , Total = 15100 , Deleted = 2400 , Problem = 0
# At 20:01:15 :: idx = 2476 , Total = 15100 , Deleted = 2475 , Problem = 0
# At 20:02:04 :: idx = 2551 , Total = 15100 , Deleted = 2550 , Problem = 0
# At 20:02:48 :: idx = 2626 , Total = 15100 , Deleted = 2625 , Problem = 0
# At 20:03:34 :: idx = 2701 , Total = 15100 , Deleted = 2700 , Problem = 0
# At 20:04:19 :: idx = 2776 , Total = 15100 , Deleted = 2775 , Problem = 0
# At 20:05:03 :: idx = 2851 , Total = 15100 , Deleted = 2850 , Problem = 0
# At 20:05:50 :: idx = 2926 , Total = 15100 , Deleted = 2925 , Problem = 0
# At 20:06:36 :: idx = 3001 , Total = 15100 , Deleted = 3000 , Problem = 0
# At 20:07:24 :: idx = 3076 , Total = 15100 , Deleted = 3075 , Problem = 0
# At 20:08:11 :: idx = 3151 , Total = 15100 , Deleted = 3150 , Problem = 0
# At 20:08:59 :: idx = 3226 , Total = 15100 , Deleted = 3225 , Problem = 0
# At 20:09:50 :: idx = 3301 , Total = 15100 , Deleted = 3300 , Problem = 0
# At 20:10:36 :: idx = 3376 , Total = 15100 , Deleted = 3375 , Problem = 0
# At 20:11:22 :: idx = 3451 , Total = 15100 , Deleted = 3450 , Problem = 0
# At 20:12:07 :: idx = 3526 , Total = 15100 , Deleted = 3525 , Problem = 0
# At 20:13:04 :: idx = 3601 , Total = 15100 , Deleted = 3600 , Problem = 0
# At 20:14:24 :: idx = 3676 , Total = 15100 , Deleted = 3675 , Problem = 0
# At 20:15:23 :: idx = 3751 , Total = 15100 , Deleted = 3750 , Problem = 0
# At 20:16:12 :: idx = 3826 , Total = 15100 , Deleted = 3825 , Problem = 0
# At 20:17:00 :: idx = 3901 , Total = 15100 , Deleted = 3900 , Problem = 0
# At 20:17:53 :: idx = 3976 , Total = 15100 , Deleted = 3975 , Problem = 0
# At 20:18:47 :: idx = 4051 , Total = 15100 , Deleted = 4050 , Problem = 0
# At 20:19:42 :: idx = 4126 , Total = 15100 , Deleted = 4125 , Problem = 0
# At 20:20:45 :: idx = 4201 , Total = 15100 , Deleted = 4200 , Problem = 0
# At 20:21:40 :: idx = 4276 , Total = 15100 , Deleted = 4275 , Problem = 0
# At 20:22:33 :: idx = 4351 , Total = 15100 , Deleted = 4350 , Problem = 0
# At 20:23:28 :: idx = 4426 , Total = 15100 , Deleted = 4425 , Problem = 0
# At 20:24:23 :: idx = 4501 , Total = 15100 , Deleted = 4500 , Problem = 0
# At 20:25:12 :: idx = 4576 , Total = 15100 , Deleted = 4575 , Problem = 0
# At 20:26:15 :: idx = 4651 , Total = 15100 , Deleted = 4650 , Problem = 0
# At 20:27:04 :: idx = 4726 , Total = 15100 , Deleted = 4725 , Problem = 0
# At 20:27:58 :: idx = 4801 , Total = 15100 , Deleted = 4800 , Problem = 0
# At 20:28:50 :: idx = 4876 , Total = 15100 , Deleted = 4875 , Problem = 0
# At 20:29:40 :: idx = 4951 , Total = 15100 , Deleted = 4950 , Problem = 0
# At 20:30:31 :: idx = 5026 , Total = 15100 , Deleted = 5025 , Problem = 0
# At 20:31:20 :: idx = 5101 , Total = 15100 , Deleted = 5100 , Problem = 0
# At 20:32:15 :: idx = 5176 , Total = 15100 , Deleted = 5175 , Problem = 0
# At 20:33:08 :: idx = 5251 , Total = 15100 , Deleted = 5250 , Problem = 0
# At 20:33:55 :: idx = 5326 , Total = 15100 , Deleted = 5325 , Problem = 0
# At 20:34:41 :: idx = 5401 , Total = 15100 , Deleted = 5400 , Problem = 0
# At 20:35:28 :: idx = 5476 , Total = 15100 , Deleted = 5475 , Problem = 0
# At 20:36:16 :: idx = 5551 , Total = 15100 , Deleted = 5550 , Problem = 0
# At 20:36:59 :: idx = 5626 , Total = 15100 , Deleted = 5625 , Problem = 0
# At 20:37:42 :: idx = 5701 , Total = 15100 , Deleted = 5700 , Problem = 0
# At 20:38:34 :: idx = 5776 , Total = 15100 , Deleted = 5775 , Problem = 0
# At 20:39:25 :: idx = 5851 , Total = 15100 , Deleted = 5850 , Problem = 0
# At 20:40:12 :: idx = 5926 , Total = 15100 , Deleted = 5925 , Problem = 0
# At 20:40:53 :: idx = 6001 , Total = 15100 , Deleted = 6000 , Problem = 0
# At 20:41:38 :: idx = 6076 , Total = 15100 , Deleted = 6075 , Problem = 0
# At 20:42:32 :: idx = 6151 , Total = 15100 , Deleted = 6150 , Problem = 0
# At 20:43:19 :: idx = 6226 , Total = 15100 , Deleted = 6225 , Problem = 0
# At 20:44:07 :: idx = 6301 , Total = 15100 , Deleted = 6300 , Problem = 0
# At 20:44:51 :: idx = 6376 , Total = 15100 , Deleted = 6375 , Problem = 0
# At 20:45:35 :: idx = 6451 , Total = 15100 , Deleted = 6450 , Problem = 0
# At 20:46:19 :: idx = 6526 , Total = 15100 , Deleted = 6525 , Problem = 0
# At 20:47:14 :: idx = 6601 , Total = 15100 , Deleted = 6600 , Problem = 0
# At 20:48:02 :: idx = 6676 , Total = 15100 , Deleted = 6675 , Problem = 0
# At 20:48:56 :: idx = 6751 , Total = 15100 , Deleted = 6750 , Problem = 0
# At 20:49:47 :: idx = 6826 , Total = 15100 , Deleted = 6825 , Problem = 0
# At 20:50:33 :: idx = 6901 , Total = 15100 , Deleted = 6900 , Problem = 0
# At 20:51:32 :: idx = 6976 , Total = 15100 , Deleted = 6975 , Problem = 0
# At 20:52:36 :: idx = 7051 , Total = 15100 , Deleted = 7050 , Problem = 0
# At 20:53:25 :: idx = 7126 , Total = 15100 , Deleted = 7125 , Problem = 0

# %% [markdown]
# ## DELETE RUN 3 - RETRIEVED WITH MAX PAGES LIMIT = 100

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv'  ## coco_train2017_118k  folder


MAX_PAGES_LIMIT = 100
files_to_delete_arr = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files', _MAX_PAGES_LIMIT = MAX_PAGES_LIMIT)
print(f"\nFew Results for query with FILES=\n{files_to_delete_arr[:10]}")
# Out:
# Query parameter built as:'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
#
# Number of itmes found = 10100
#
#
#
#
# Maximum page limit reached 100 and breaking
#
#
#
# Few Results for query with FILES=
# [{'name': '000000036382.jpg', 'id': '1HUBnYuneSn4VP8gx36KovEZ3jKCQgvoU'}, {'name': '000000375552.jpg', 'id': '1bwbCPXl1hYrHh8vJUEzauImmwpKNDsej'}, {'name': '000000282603.jpg', 'id': '1O_ai3zB8tQY7EBP2Thk1dAAvsapqKUQs'}, {'name': '000000362795.jpg', 'id': '116TUzpq6DuKOxhckqaypxR09EI1i1k5a'}, {'name': '000000318183.jpg', 'id': '1vg0uEBx3oOrDA6hYkcF_cG3OxUC7wCew'}, {'name': '000000009479.jpg', 'id': '1d6oYaPBITe0zOvjgkxeq4t_FqnbFHQvo'}, {'name': '000000497542.jpg', 'id': '14TyY9gV5UVwaKDPIkr2L7ihR4rAlYqfH'}, {'name': '000000021294.jpg', 'id': '1OffnDBhpyoh14DHlTOgwkBZykh7Fm3c3'}, {'name': '000000308775.jpg', 'id': '1iG3u9PWoDU0QNSyvg7kHdJmiVCUZVvmU'}, {'name': '000000355578.jpg', 'id': '1oPJqkyaiCB3iOv3QZe59ZKx92PQUMD8n'}]

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 50
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")
# Out:
# Input array has 10100 files to delete
# At 17:12:45 :: idx = 1 , Total = 10100 , Deleted = 0 , Problem = 0
# At 17:13:22 :: idx = 51 , Total = 10100 , Deleted = 50 , Problem = 0
# At 17:14:02 :: idx = 101 , Total = 10100 , Deleted = 100 , Problem = 0
# At 17:14:34 :: idx = 151 , Total = 10100 , Deleted = 150 , Problem = 0
# At 17:15:04 :: idx = 201 , Total = 10100 , Deleted = 200 , Problem = 0
# At 17:15:36 :: idx = 251 , Total = 10100 , Deleted = 250 , Problem = 0
# At 17:16:08 :: idx = 301 , Total = 10100 , Deleted = 300 , Problem = 0
# At 17:16:40 :: idx = 351 , Total = 10100 , Deleted = 350 , Problem = 0
# At 17:17:13 :: idx = 401 , Total = 10100 , Deleted = 400 , Problem = 0
# At 17:17:43 :: idx = 451 , Total = 10100 , Deleted = 450 , Problem = 0
# At 17:18:13 :: idx = 501 , Total = 10100 , Deleted = 500 , Problem = 0
# At 17:18:42 :: idx = 551 , Total = 10100 , Deleted = 550 , Problem = 0
# At 17:19:13 :: idx = 601 , Total = 10100 , Deleted = 600 , Problem = 0
# At 17:19:41 :: idx = 651 , Total = 10100 , Deleted = 650 , Problem = 0
# At 17:20:10 :: idx = 701 , Total = 10100 , Deleted = 700 , Problem = 0
# At 17:21:01 :: idx = 751 , Total = 10100 , Deleted = 750 , Problem = 0
# At 17:21:33 :: idx = 801 , Total = 10100 , Deleted = 800 , Problem = 0
# At 17:22:01 :: idx = 851 , Total = 10100 , Deleted = 850 , Problem = 0
# At 17:22:32 :: idx = 901 , Total = 10100 , Deleted = 900 , Problem = 0
# At 17:23:05 :: idx = 951 , Total = 10100 , Deleted = 950 , Problem = 0
# At 17:23:36 :: idx = 1001 , Total = 10100 , Deleted = 1000 , Problem = 0
# At 17:24:10 :: idx = 1051 , Total = 10100 , Deleted = 1050 , Problem = 0
# At 17:24:45 :: idx = 1101 , Total = 10100 , Deleted = 1100 , Problem = 0
# At 17:25:16 :: idx = 1151 , Total = 10100 , Deleted = 1150 , Problem = 0
# At 17:25:45 :: idx = 1201 , Total = 10100 , Deleted = 1200 , Problem = 0
# At 17:26:16 :: idx = 1251 , Total = 10100 , Deleted = 1250 , Problem = 0
# At 17:26:47 :: idx = 1301 , Total = 10100 , Deleted = 1300 , Problem = 0
# At 17:27:18 :: idx = 1351 , Total = 10100 , Deleted = 1350 , Problem = 0
# At 17:27:47 :: idx = 1401 , Total = 10100 , Deleted = 1400 , Problem = 0
# At 17:28:16 :: idx = 1451 , Total = 10100 , Deleted = 1450 , Problem = 0
# At 17:28:44 :: idx = 1501 , Total = 10100 , Deleted = 1500 , Problem = 0
# At 17:29:14 :: idx = 1551 , Total = 10100 , Deleted = 1550 , Problem = 0
# At 17:29:49 :: idx = 1601 , Total = 10100 , Deleted = 1600 , Problem = 0
# At 17:30:22 :: idx = 1651 , Total = 10100 , Deleted = 1650 , Problem = 0
# At 17:30:50 :: idx = 1701 , Total = 10100 , Deleted = 1700 , Problem = 0
# At 17:31:23 :: idx = 1751 , Total = 10100 , Deleted = 1750 , Problem = 0
# At 17:31:57 :: idx = 1801 , Total = 10100 , Deleted = 1800 , Problem = 0
# At 17:32:29 :: idx = 1851 , Total = 10100 , Deleted = 1850 , Problem = 0
# At 17:33:09 :: idx = 1901 , Total = 10100 , Deleted = 1900 , Problem = 0
# At 17:33:42 :: idx = 1951 , Total = 10100 , Deleted = 1950 , Problem = 0
# At 17:34:12 :: idx = 2001 , Total = 10100 , Deleted = 2000 , Problem = 0
# At 17:34:43 :: idx = 2051 , Total = 10100 , Deleted = 2050 , Problem = 0
# At 17:35:14 :: idx = 2101 , Total = 10100 , Deleted = 2100 , Problem = 0
# At 17:35:43 :: idx = 2151 , Total = 10100 , Deleted = 2150 , Problem = 0
# At 17:36:20 :: idx = 2201 , Total = 10100 , Deleted = 2200 , Problem = 0
# At 17:36:54 :: idx = 2251 , Total = 10100 , Deleted = 2250 , Problem = 0
# At 17:37:21 :: idx = 2301 , Total = 10100 , Deleted = 2300 , Problem = 0
# At 17:37:48 :: idx = 2351 , Total = 10100 , Deleted = 2350 , Problem = 0
# At 17:38:15 :: idx = 2401 , Total = 10100 , Deleted = 2400 , Problem = 0
# At 17:38:41 :: idx = 2451 , Total = 10100 , Deleted = 2450 , Problem = 0
# At 17:39:14 :: idx = 2501 , Total = 10100 , Deleted = 2500 , Problem = 0
# At 17:39:40 :: idx = 2551 , Total = 10100 , Deleted = 2550 , Problem = 0
# At 17:40:07 :: idx = 2601 , Total = 10100 , Deleted = 2600 , Problem = 0
# At 17:40:35 :: idx = 2651 , Total = 10100 , Deleted = 2650 , Problem = 0
# At 17:41:05 :: idx = 2701 , Total = 10100 , Deleted = 2700 , Problem = 0
# At 17:41:30 :: idx = 2751 , Total = 10100 , Deleted = 2750 , Problem = 0
# At 17:41:54 :: idx = 2801 , Total = 10100 , Deleted = 2800 , Problem = 0
# At 17:42:19 :: idx = 2851 , Total = 10100 , Deleted = 2850 , Problem = 0
# At 17:42:46 :: idx = 2901 , Total = 10100 , Deleted = 2900 , Problem = 0
# At 17:43:12 :: idx = 2951 , Total = 10100 , Deleted = 2950 , Problem = 0
# At 17:43:37 :: idx = 3001 , Total = 10100 , Deleted = 3000 , Problem = 0
# At 17:44:02 :: idx = 3051 , Total = 10100 , Deleted = 3050 , Problem = 0
# At 17:44:30 :: idx = 3101 , Total = 10100 , Deleted = 3100 , Problem = 0
# At 17:44:59 :: idx = 3151 , Total = 10100 , Deleted = 3150 , Problem = 0
# At 17:45:31 :: idx = 3201 , Total = 10100 , Deleted = 3200 , Problem = 0
# At 17:45:56 :: idx = 3251 , Total = 10100 , Deleted = 3250 , Problem = 0
# At 17:46:23 :: idx = 3301 , Total = 10100 , Deleted = 3300 , Problem = 0
# At 17:46:49 :: idx = 3351 , Total = 10100 , Deleted = 3350 , Problem = 0
# At 17:47:16 :: idx = 3401 , Total = 10100 , Deleted = 3400 , Problem = 0
# At 17:47:46 :: idx = 3451 , Total = 10100 , Deleted = 3450 , Problem = 0
# At 17:48:17 :: idx = 3501 , Total = 10100 , Deleted = 3500 , Problem = 0
# At 17:48:47 :: idx = 3551 , Total = 10100 , Deleted = 3550 , Problem = 0
# At 17:49:22 :: idx = 3601 , Total = 10100 , Deleted = 3600 , Problem = 0
# At 17:49:54 :: idx = 3651 , Total = 10100 , Deleted = 3650 , Problem = 0
# At 17:50:30 :: idx = 3701 , Total = 10100 , Deleted = 3700 , Problem = 0
# At 17:51:11 :: idx = 3751 , Total = 10100 , Deleted = 3750 , Problem = 0
# At 17:51:51 :: idx = 3801 , Total = 10100 , Deleted = 3800 , Problem = 0
# At 17:52:26 :: idx = 3851 , Total = 10100 , Deleted = 3850 , Problem = 0
# At 17:52:57 :: idx = 3901 , Total = 10100 , Deleted = 3900 , Problem = 0
# At 17:53:28 :: idx = 3951 , Total = 10100 , Deleted = 3950 , Problem = 0
# At 17:53:55 :: idx = 4001 , Total = 10100 , Deleted = 4000 , Problem = 0
# At 17:54:28 :: idx = 4051 , Total = 10100 , Deleted = 4050 , Problem = 0
# At 17:54:59 :: idx = 4101 , Total = 10100 , Deleted = 4100 , Problem = 0
# At 17:55:29 :: idx = 4151 , Total = 10100 , Deleted = 4150 , Problem = 0
# At 17:56:01 :: idx = 4201 , Total = 10100 , Deleted = 4200 , Problem = 0
# At 17:56:32 :: idx = 4251 , Total = 10100 , Deleted = 4250 , Problem = 0
# At 17:57:05 :: idx = 4301 , Total = 10100 , Deleted = 4300 , Problem = 0
# At 17:57:29 :: idx = 4351 , Total = 10100 , Deleted = 4350 , Problem = 0
# At 17:58:01 :: idx = 4401 , Total = 10100 , Deleted = 4400 , Problem = 0
# At 17:58:28 :: idx = 4451 , Total = 10100 , Deleted = 4450 , Problem = 0
# At 17:59:02 :: idx = 4501 , Total = 10100 , Deleted = 4500 , Problem = 0
# At 17:59:37 :: idx = 4551 , Total = 10100 , Deleted = 4550 , Problem = 0
# At 18:00:07 :: idx = 4601 , Total = 10100 , Deleted = 4600 , Problem = 0
# At 18:00:35 :: idx = 4651 , Total = 10100 , Deleted = 4650 , Problem = 0
# At 18:01:01 :: idx = 4701 , Total = 10100 , Deleted = 4700 , Problem = 0
# At 18:01:30 :: idx = 4751 , Total = 10100 , Deleted = 4750 , Problem = 0
# At 18:01:57 :: idx = 4801 , Total = 10100 , Deleted = 4800 , Problem = 0
# At 18:02:25 :: idx = 4851 , Total = 10100 , Deleted = 4850 , Problem = 0
# At 18:02:54 :: idx = 4901 , Total = 10100 , Deleted = 4900 , Problem = 0
# At 18:03:19 :: idx = 4951 , Total = 10100 , Deleted = 4950 , Problem = 0
# At 18:03:52 :: idx = 5001 , Total = 10100 , Deleted = 5000 , Problem = 0
# At 18:04:22 :: idx = 5051 , Total = 10100 , Deleted = 5050 , Problem = 0
# At 18:05:00 :: idx = 5101 , Total = 10100 , Deleted = 5100 , Problem = 0
# At 18:05:32 :: idx = 5151 , Total = 10100 , Deleted = 5150 , Problem = 0
# At 18:06:00 :: idx = 5201 , Total = 10100 , Deleted = 5200 , Problem = 0
# At 18:06:32 :: idx = 5251 , Total = 10100 , Deleted = 5250 , Problem = 0
# At 18:07:05 :: idx = 5301 , Total = 10100 , Deleted = 5300 , Problem = 0
# At 18:07:46 :: idx = 5351 , Total = 10100 , Deleted = 5350 , Problem = 0
# At 18:08:15 :: idx = 5401 , Total = 10100 , Deleted = 5400 , Problem = 0
# At 18:08:48 :: idx = 5451 , Total = 10100 , Deleted = 5450 , Problem = 0
# At 18:09:16 :: idx = 5501 , Total = 10100 , Deleted = 5500 , Problem = 0
# At 18:09:44 :: idx = 5551 , Total = 10100 , Deleted = 5550 , Problem = 0
# At 18:10:12 :: idx = 5601 , Total = 10100 , Deleted = 5600 , Problem = 0
# At 18:10:40 :: idx = 5651 , Total = 10100 , Deleted = 5650 , Problem = 0
# At 18:11:08 :: idx = 5701 , Total = 10100 , Deleted = 5700 , Problem = 0
# At 18:11:34 :: idx = 5751 , Total = 10100 , Deleted = 5750 , Problem = 0
# At 18:12:06 :: idx = 5801 , Total = 10100 , Deleted = 5800 , Problem = 0
# At 18:12:32 :: idx = 5851 , Total = 10100 , Deleted = 5850 , Problem = 0
# At 18:12:58 :: idx = 5901 , Total = 10100 , Deleted = 5900 , Problem = 0
# At 18:13:30 :: idx = 5951 , Total = 10100 , Deleted = 5950 , Problem = 0
# At 18:13:55 :: idx = 6001 , Total = 10100 , Deleted = 6000 , Problem = 0
# At 18:14:21 :: idx = 6051 , Total = 10100 , Deleted = 6050 , Problem = 0
# At 18:14:48 :: idx = 6101 , Total = 10100 , Deleted = 6100 , Problem = 0
# At 18:15:17 :: idx = 6151 , Total = 10100 , Deleted = 6150 , Problem = 0
# At 18:15:46 :: idx = 6201 , Total = 10100 , Deleted = 6200 , Problem = 0
# At 18:16:24 :: idx = 6251 , Total = 10100 , Deleted = 6250 , Problem = 0
# At 18:16:51 :: idx = 6301 , Total = 10100 , Deleted = 6300 , Problem = 0
# At 18:17:22 :: idx = 6351 , Total = 10100 , Deleted = 6350 , Problem = 0
# At 18:17:57 :: idx = 6401 , Total = 10100 , Deleted = 6400 , Problem = 0
# At 18:18:25 :: idx = 6451 , Total = 10100 , Deleted = 6450 , Problem = 0
# At 18:18:53 :: idx = 6501 , Total = 10100 , Deleted = 6500 , Problem = 0
# At 18:19:23 :: idx = 6551 , Total = 10100 , Deleted = 6550 , Problem = 0
# At 18:19:53 :: idx = 6601 , Total = 10100 , Deleted = 6600 , Problem = 0
# At 18:20:21 :: idx = 6651 , Total = 10100 , Deleted = 6650 , Problem = 0
# At 18:20:48 :: idx = 6701 , Total = 10100 , Deleted = 6700 , Problem = 0
# At 18:21:24 :: idx = 6751 , Total = 10100 , Deleted = 6750 , Problem = 0
# At 18:21:55 :: idx = 6801 , Total = 10100 , Deleted = 6800 , Problem = 0
# At 18:22:22 :: idx = 6851 , Total = 10100 , Deleted = 6850 , Problem = 0
# At 18:23:03 :: idx = 6901 , Total = 10100 , Deleted = 6900 , Problem = 0
# At 18:23:49 :: idx = 6951 , Total = 10100 , Deleted = 6950 , Problem = 0
# At 18:24:16 :: idx = 7001 , Total = 10100 , Deleted = 7000 , Problem = 0
# At 18:24:48 :: idx = 7051 , Total = 10100 , Deleted = 7050 , Problem = 0
# At 18:25:13 :: idx = 7101 , Total = 10100 , Deleted = 7100 , Problem = 0
# At 18:25:41 :: idx = 7151 , Total = 10100 , Deleted = 7150 , Problem = 0
# At 18:26:07 :: idx = 7201 , Total = 10100 , Deleted = 7200 , Problem = 0
# At 18:26:35 :: idx = 7251 , Total = 10100 , Deleted = 7250 , Problem = 0
# At 18:27:03 :: idx = 7301 , Total = 10100 , Deleted = 7300 , Problem = 0
# At 18:27:31 :: idx = 7351 , Total = 10100 , Deleted = 7350 , Problem = 0
# At 18:28:00 :: idx = 7401 , Total = 10100 , Deleted = 7400 , Problem = 0
# At 18:28:24 :: idx = 7451 , Total = 10100 , Deleted = 7450 , Problem = 0
# At 18:28:52 :: idx = 7501 , Total = 10100 , Deleted = 7500 , Problem = 0
# At 18:29:19 :: idx = 7551 , Total = 10100 , Deleted = 7550 , Problem = 0
# At 18:29:49 :: idx = 7601 , Total = 10100 , Deleted = 7600 , Problem = 0
# At 18:30:30 :: idx = 7651 , Total = 10100 , Deleted = 7650 , Problem = 0
# At 18:31:06 :: idx = 7701 , Total = 10100 , Deleted = 7700 , Problem = 0
# At 18:31:51 :: idx = 7751 , Total = 10100 , Deleted = 7750 , Problem = 0
# At 18:32:41 :: idx = 7801 , Total = 10100 , Deleted = 7800 , Problem = 0
# At 18:33:30 :: idx = 7851 , Total = 10100 , Deleted = 7850 , Problem = 0
# At 18:34:09 :: idx = 7901 , Total = 10100 , Deleted = 7900 , Problem = 0
# At 18:35:09 :: idx = 7951 , Total = 10100 , Deleted = 7950 , Problem = 0
# At 18:36:30 :: idx = 8001 , Total = 10100 , Deleted = 8000 , Problem = 0
# At 18:37:38 :: idx = 8051 , Total = 10100 , Deleted = 8050 , Problem = 0
# At 18:38:46 :: idx = 8101 , Total = 10100 , Deleted = 8100 , Problem = 0
# At 18:39:46 :: idx = 8151 , Total = 10100 , Deleted = 8150 , Problem = 0
# At 18:40:50 :: idx = 8201 , Total = 10100 , Deleted = 8200 , Problem = 0
# At 18:41:56 :: idx = 8251 , Total = 10100 , Deleted = 8250 , Problem = 0
# At 18:42:42 :: idx = 8301 , Total = 10100 , Deleted = 8300 , Problem = 0
# At 18:43:37 :: idx = 8351 , Total = 10100 , Deleted = 8350 , Problem = 0
# At 18:44:30 :: idx = 8401 , Total = 10100 , Deleted = 8400 , Problem = 0
# At 18:45:27 :: idx = 8451 , Total = 10100 , Deleted = 8450 , Problem = 0
# At 18:46:47 :: idx = 8501 , Total = 10100 , Deleted = 8500 , Problem = 0
# At 18:48:00 :: idx = 8551 , Total = 10100 , Deleted = 8550 , Problem = 0
# At 18:48:54 :: idx = 8601 , Total = 10100 , Deleted = 8600 , Problem = 0
# At 18:49:44 :: idx = 8651 , Total = 10100 , Deleted = 8650 , Problem = 0
# At 18:50:31 :: idx = 8701 , Total = 10100 , Deleted = 8700 , Problem = 0
# At 18:51:15 :: idx = 8751 , Total = 10100 , Deleted = 8750 , Problem = 0
# At 18:52:12 :: idx = 8801 , Total = 10100 , Deleted = 8800 , Problem = 0
# At 18:53:04 :: idx = 8851 , Total = 10100 , Deleted = 8850 , Problem = 0
# At 18:53:55 :: idx = 8901 , Total = 10100 , Deleted = 8900 , Problem = 0
# At 18:54:49 :: idx = 8951 , Total = 10100 , Deleted = 8950 , Problem = 0
# At 18:55:34 :: idx = 9001 , Total = 10100 , Deleted = 9000 , Problem = 0
# At 18:56:21 :: idx = 9051 , Total = 10100 , Deleted = 9050 , Problem = 0
# At 18:57:12 :: idx = 9101 , Total = 10100 , Deleted = 9100 , Problem = 0
# At 18:58:48 :: idx = 9151 , Total = 10100 , Deleted = 9150 , Problem = 0
# At 18:59:46 :: idx = 9201 , Total = 10100 , Deleted = 9200 , Problem = 0
# At 19:00:41 :: idx = 9251 , Total = 10100 , Deleted = 9250 , Problem = 0
# At 19:01:20 :: idx = 9301 , Total = 10100 , Deleted = 9300 , Problem = 0
# At 19:02:14 :: idx = 9351 , Total = 10100 , Deleted = 9350 , Problem = 0
# At 19:03:06 :: idx = 9401 , Total = 10100 , Deleted = 9400 , Problem = 0
# At 19:04:12 :: idx = 9451 , Total = 10100 , Deleted = 9450 , Problem = 0
# At 19:05:18 :: idx = 9501 , Total = 10100 , Deleted = 9500 , Problem = 0
# At 19:06:13 :: idx = 9551 , Total = 10100 , Deleted = 9550 , Problem = 0
# At 19:06:54 :: idx = 9601 , Total = 10100 , Deleted = 9600 , Problem = 0
# At 19:07:35 :: idx = 9651 , Total = 10100 , Deleted = 9650 , Problem = 0
# At 19:08:13 :: idx = 9701 , Total = 10100 , Deleted = 9700 , Problem = 0
# At 19:08:56 :: idx = 9751 , Total = 10100 , Deleted = 9750 , Problem = 0
# At 19:09:46 :: idx = 9801 , Total = 10100 , Deleted = 9800 , Problem = 0
# At 19:10:37 :: idx = 9851 , Total = 10100 , Deleted = 9850 , Problem = 0
# At 19:11:23 :: idx = 9901 , Total = 10100 , Deleted = 9900 , Problem = 0
# At 19:12:12 :: idx = 9951 , Total = 10100 , Deleted = 9950 , Problem = 0
# At 19:13:00 :: idx = 10001 , Total = 10100 , Deleted = 10000 , Problem = 0
# At 19:13:49 :: idx = 10051 , Total = 10100 , Deleted = 10050 , Problem = 0
#
#
# Summary :: Total = 10100 , Deleted = 10100 , Problem = 0
# len(prob_files) = 0

# %% [markdown]
# ## DELETE RUN 2 - RETRIEVED WITH MAX PAGES LIMIT = 20

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv'  ## coco_train2017_118k  folder


MAX_PAGES_LIMIT = 20
files_to_delete_arr = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files', _MAX_PAGES_LIMIT = MAX_PAGES_LIMIT)
print(f"\nFew Results for query with FILES=\n{files_to_delete_arr[:10]}")
# Out:
# Query parameter built as:'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
#
# Number of itmes found = 2100
#
#
#
#
# Maximum page limit reached 20 and breaking
#
#
#
# Few Results for query with FILES=
# [{'name': '000000081971.jpg', 'id': '1nsL_AhK6imbhNvuJPd280t4I9y5Mi4F8'}, {'name': '000000471698.jpg', 'id': '1ZlvB4x7bMoqBfwFWA4AE5H04cU1yWkX1'}, {'name': '000000488897.jpg', 'id': '1dl0c6YDV6LtvUF0iusjZJHaFceQQxmja'}, {'name': '000000138999.jpg', 'id': '1MOeFOVTjqHm5SRRN9k2sIZLcyTkVymBF'}, {'name': '000000101369.jpg', 'id': '1bFVJj-QqrR5lSjZY6lBp8O9ks-uRFY3Y'}, {'name': '000000345265.jpg', 'id': '1wFEa3l_zjpUVBTw9uASIclJs15VJT1-k'}, {'name': '000000333775.jpg', 'id': '1EHPI-Gg52PI2alcioG23ztSmL5O6lRoc'}, {'name': '000000558166.jpg', 'id': '1CpQ88VzQu4xS1ChD42ap5KpXm9zMwGaR'}, {'name': '000000341455.jpg', 'id': '12HH4QA1ME2n3kRYyeHI5OFiHOqKzqE4m'}, {'name': '000000463175.jpg', 'id': '1pmUdQjogOpW1Z5jmqsVaPxh4ITE2cMFi'}]

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 20
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")
# Out:
# Input array has 2100 files to delete
# At 16:44:07 :: idx = 1 , Total = 2100 , Deleted = 0 , Problem = 0
# At 16:44:21 :: idx = 21 , Total = 2100 , Deleted = 20 , Problem = 0
# At 16:44:34 :: idx = 41 , Total = 2100 , Deleted = 40 , Problem = 0
# At 16:44:49 :: idx = 61 , Total = 2100 , Deleted = 60 , Problem = 0
# At 16:45:02 :: idx = 81 , Total = 2100 , Deleted = 80 , Problem = 0
# At 16:45:18 :: idx = 101 , Total = 2100 , Deleted = 100 , Problem = 0
# At 16:45:31 :: idx = 121 , Total = 2100 , Deleted = 120 , Problem = 0
# At 16:45:46 :: idx = 141 , Total = 2100 , Deleted = 140 , Problem = 0
# At 16:46:00 :: idx = 161 , Total = 2100 , Deleted = 160 , Problem = 0
# At 16:46:13 :: idx = 181 , Total = 2100 , Deleted = 180 , Problem = 0
# At 16:46:31 :: idx = 201 , Total = 2100 , Deleted = 200 , Problem = 0
# At 16:46:49 :: idx = 221 , Total = 2100 , Deleted = 220 , Problem = 0
# At 16:47:05 :: idx = 241 , Total = 2100 , Deleted = 240 , Problem = 0
# At 16:47:17 :: idx = 261 , Total = 2100 , Deleted = 260 , Problem = 0
# At 16:47:31 :: idx = 281 , Total = 2100 , Deleted = 280 , Problem = 0
# At 16:47:44 :: idx = 301 , Total = 2100 , Deleted = 300 , Problem = 0
# At 16:47:57 :: idx = 321 , Total = 2100 , Deleted = 320 , Problem = 0
# At 16:48:13 :: idx = 341 , Total = 2100 , Deleted = 340 , Problem = 0
# At 16:48:28 :: idx = 361 , Total = 2100 , Deleted = 360 , Problem = 0
# At 16:48:43 :: idx = 381 , Total = 2100 , Deleted = 380 , Problem = 0
# At 16:48:56 :: idx = 401 , Total = 2100 , Deleted = 400 , Problem = 0
# At 16:49:10 :: idx = 421 , Total = 2100 , Deleted = 420 , Problem = 0
# At 16:49:22 :: idx = 441 , Total = 2100 , Deleted = 440 , Problem = 0
# At 16:49:33 :: idx = 461 , Total = 2100 , Deleted = 460 , Problem = 0
# At 16:49:46 :: idx = 481 , Total = 2100 , Deleted = 480 , Problem = 0
# At 16:49:58 :: idx = 501 , Total = 2100 , Deleted = 500 , Problem = 0
# At 16:50:09 :: idx = 521 , Total = 2100 , Deleted = 520 , Problem = 0
# At 16:50:22 :: idx = 541 , Total = 2100 , Deleted = 540 , Problem = 0
# At 16:50:33 :: idx = 561 , Total = 2100 , Deleted = 560 , Problem = 0
# At 16:50:46 :: idx = 581 , Total = 2100 , Deleted = 580 , Problem = 0
# At 16:50:58 :: idx = 601 , Total = 2100 , Deleted = 600 , Problem = 0
# At 16:51:09 :: idx = 621 , Total = 2100 , Deleted = 620 , Problem = 0
# At 16:51:20 :: idx = 641 , Total = 2100 , Deleted = 640 , Problem = 0
# At 16:51:32 :: idx = 661 , Total = 2100 , Deleted = 660 , Problem = 0
# At 16:51:46 :: idx = 681 , Total = 2100 , Deleted = 680 , Problem = 0
# At 16:51:58 :: idx = 701 , Total = 2100 , Deleted = 700 , Problem = 0
# At 16:52:13 :: idx = 721 , Total = 2100 , Deleted = 720 , Problem = 0
# At 16:52:25 :: idx = 741 , Total = 2100 , Deleted = 740 , Problem = 0
# At 16:52:39 :: idx = 761 , Total = 2100 , Deleted = 760 , Problem = 0
# At 16:52:49 :: idx = 781 , Total = 2100 , Deleted = 780 , Problem = 0
# At 16:53:01 :: idx = 801 , Total = 2100 , Deleted = 800 , Problem = 0
# At 16:53:13 :: idx = 821 , Total = 2100 , Deleted = 820 , Problem = 0
# At 16:53:24 :: idx = 841 , Total = 2100 , Deleted = 840 , Problem = 0
# At 16:53:36 :: idx = 861 , Total = 2100 , Deleted = 860 , Problem = 0
# At 16:53:49 :: idx = 881 , Total = 2100 , Deleted = 880 , Problem = 0
# At 16:54:17 :: idx = 901 , Total = 2100 , Deleted = 900 , Problem = 0
# At 16:54:29 :: idx = 921 , Total = 2100 , Deleted = 920 , Problem = 0
# At 16:54:43 :: idx = 941 , Total = 2100 , Deleted = 940 , Problem = 0
# At 16:54:57 :: idx = 961 , Total = 2100 , Deleted = 960 , Problem = 0
# At 16:55:09 :: idx = 981 , Total = 2100 , Deleted = 980 , Problem = 0
# At 16:55:21 :: idx = 1001 , Total = 2100 , Deleted = 1000 , Problem = 0
# At 16:55:34 :: idx = 1021 , Total = 2100 , Deleted = 1020 , Problem = 0
# At 16:55:45 :: idx = 1041 , Total = 2100 , Deleted = 1040 , Problem = 0
# At 16:55:57 :: idx = 1061 , Total = 2100 , Deleted = 1060 , Problem = 0
# At 16:56:10 :: idx = 1081 , Total = 2100 , Deleted = 1080 , Problem = 0
# At 16:56:21 :: idx = 1101 , Total = 2100 , Deleted = 1100 , Problem = 0
# At 16:56:34 :: idx = 1121 , Total = 2100 , Deleted = 1120 , Problem = 0
# At 16:56:45 :: idx = 1141 , Total = 2100 , Deleted = 1140 , Problem = 0
# At 16:56:57 :: idx = 1161 , Total = 2100 , Deleted = 1160 , Problem = 0
# At 16:57:09 :: idx = 1181 , Total = 2100 , Deleted = 1180 , Problem = 0
# At 16:57:19 :: idx = 1201 , Total = 2100 , Deleted = 1200 , Problem = 0
# At 16:57:30 :: idx = 1221 , Total = 2100 , Deleted = 1220 , Problem = 0
# At 16:57:43 :: idx = 1241 , Total = 2100 , Deleted = 1240 , Problem = 0
# At 16:57:53 :: idx = 1261 , Total = 2100 , Deleted = 1260 , Problem = 0
# At 16:58:03 :: idx = 1281 , Total = 2100 , Deleted = 1280 , Problem = 0
# At 16:58:13 :: idx = 1301 , Total = 2100 , Deleted = 1300 , Problem = 0
# At 16:58:23 :: idx = 1321 , Total = 2100 , Deleted = 1320 , Problem = 0
# At 16:58:34 :: idx = 1341 , Total = 2100 , Deleted = 1340 , Problem = 0
# At 16:58:44 :: idx = 1361 , Total = 2100 , Deleted = 1360 , Problem = 0
# At 16:58:54 :: idx = 1381 , Total = 2100 , Deleted = 1380 , Problem = 0
# At 16:59:05 :: idx = 1401 , Total = 2100 , Deleted = 1400 , Problem = 0
# At 16:59:15 :: idx = 1421 , Total = 2100 , Deleted = 1420 , Problem = 0
# At 16:59:26 :: idx = 1441 , Total = 2100 , Deleted = 1440 , Problem = 0
# At 16:59:37 :: idx = 1461 , Total = 2100 , Deleted = 1460 , Problem = 0
# At 16:59:48 :: idx = 1481 , Total = 2100 , Deleted = 1480 , Problem = 0
# At 16:59:58 :: idx = 1501 , Total = 2100 , Deleted = 1500 , Problem = 0
# At 17:00:08 :: idx = 1521 , Total = 2100 , Deleted = 1520 , Problem = 0
# At 17:00:19 :: idx = 1541 , Total = 2100 , Deleted = 1540 , Problem = 0
# At 17:00:29 :: idx = 1561 , Total = 2100 , Deleted = 1560 , Problem = 0
# At 17:00:39 :: idx = 1581 , Total = 2100 , Deleted = 1580 , Problem = 0
# At 17:00:49 :: idx = 1601 , Total = 2100 , Deleted = 1600 , Problem = 0
# At 17:01:00 :: idx = 1621 , Total = 2100 , Deleted = 1620 , Problem = 0
# At 17:01:12 :: idx = 1641 , Total = 2100 , Deleted = 1640 , Problem = 0
# At 17:01:25 :: idx = 1661 , Total = 2100 , Deleted = 1660 , Problem = 0
# At 17:01:37 :: idx = 1681 , Total = 2100 , Deleted = 1680 , Problem = 0
# At 17:01:50 :: idx = 1701 , Total = 2100 , Deleted = 1700 , Problem = 0
# At 17:02:00 :: idx = 1721 , Total = 2100 , Deleted = 1720 , Problem = 0
# At 17:02:12 :: idx = 1741 , Total = 2100 , Deleted = 1740 , Problem = 0
# At 17:02:25 :: idx = 1761 , Total = 2100 , Deleted = 1760 , Problem = 0
# At 17:02:37 :: idx = 1781 , Total = 2100 , Deleted = 1780 , Problem = 0
# At 17:02:49 :: idx = 1801 , Total = 2100 , Deleted = 1800 , Problem = 0
# At 17:03:01 :: idx = 1821 , Total = 2100 , Deleted = 1820 , Problem = 0
# At 17:03:16 :: idx = 1841 , Total = 2100 , Deleted = 1840 , Problem = 0
# At 17:03:29 :: idx = 1861 , Total = 2100 , Deleted = 1860 , Problem = 0
# At 17:03:41 :: idx = 1881 , Total = 2100 , Deleted = 1880 , Problem = 0
# At 17:03:53 :: idx = 1901 , Total = 2100 , Deleted = 1900 , Problem = 0
# At 17:04:09 :: idx = 1921 , Total = 2100 , Deleted = 1920 , Problem = 0
# At 17:04:22 :: idx = 1941 , Total = 2100 , Deleted = 1940 , Problem = 0
# At 17:04:33 :: idx = 1961 , Total = 2100 , Deleted = 1960 , Problem = 0
# At 17:04:45 :: idx = 1981 , Total = 2100 , Deleted = 1980 , Problem = 0
# At 17:05:01 :: idx = 2001 , Total = 2100 , Deleted = 2000 , Problem = 0
# At 17:05:13 :: idx = 2021 , Total = 2100 , Deleted = 2020 , Problem = 0
# At 17:05:27 :: idx = 2041 , Total = 2100 , Deleted = 2040 , Problem = 0
# At 17:05:42 :: idx = 2061 , Total = 2100 , Deleted = 2060 , Problem = 0
# At 17:05:54 :: idx = 2081 , Total = 2100 , Deleted = 2080 , Problem = 0
#
#
# Summary :: Total = 2100 , Deleted = 2100 , Problem = 0
# len(prob_files) = 0

# %% [markdown]
# ## DELETE RUN 1 - RETRIEVED WITH MAX PAGES LIMIT = 3 (DEFAULT VALUE WAS USED)

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv'  ## coco_train2017_118k  folder

files_to_delete_arr = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files')
print(f"\nFew Results for query with FILES=\n{files_to_delete_arr[:10]}")
# Out:
# Query parameter built as:'1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
#
# Number of itmes found = 400
#
#
#
#
# Maximum page limit reached 3 and breaking
#
#
#
# Few Results for query with FILES=
# [{'name': '000000081971.jpg', 'id': '1nsL_AhK6imbhNvuJPd280t4I9y5Mi4F8'}, {'name': '000000471698.jpg', 'id': '1ZlvB4x7bMoqBfwFWA4AE5H04cU1yWkX1'}, {'name': '000000488897.jpg', 'id': '1dl0c6YDV6LtvUF0iusjZJHaFceQQxmja'}, {'name': '000000138999.jpg', 'id': '1MOeFOVTjqHm5SRRN9k2sIZLcyTkVymBF'}, {'name': '000000101369.jpg', 'id': '1bFVJj-QqrR5lSjZY6lBp8O9ks-uRFY3Y'}, {'name': '000000345265.jpg', 'id': '1wFEa3l_zjpUVBTw9uASIclJs15VJT1-k'}, {'name': '000000333775.jpg', 'id': '1EHPI-Gg52PI2alcioG23ztSmL5O6lRoc'}, {'name': '000000558166.jpg', 'id': '1CpQ88VzQu4xS1ChD42ap5KpXm9zMwGaR'}, {'name': '000000341455.jpg', 'id': '12HH4QA1ME2n3kRYyeHI5OFiHOqKzqE4m'}, {'name': '000000463175.jpg', 'id': '1pmUdQjogOpW1Z5jmqsVaPxh4ITE2cMFi'}]

# %%
## DELETE THE FILES using the dict info retrieved earlier
status_freq = 50
prob_files , cnt_total, cnt_del, cnt_prob = delete_file_items(service, files_to_delete_arr, status_freq)
print(f"len(prob_files) = {len(prob_files)}")
# Out:
# Input array has 400 files to delete
# At 16:25:48 :: idx = 1 , Total = 400 , Deleted = 0 , Problem = 0
# At 16:26:38 :: idx = 51 , Total = 400 , Deleted = 50 , Problem = 0
# At 16:27:28 :: idx = 101 , Total = 400 , Deleted = 100 , Problem = 0
# At 16:28:14 :: idx = 151 , Total = 400 , Deleted = 150 , Problem = 0
# At 16:28:56 :: idx = 201 , Total = 400 , Deleted = 200 , Problem = 0
# At 16:29:33 :: idx = 251 , Total = 400 , Deleted = 250 , Problem = 0
# At 16:30:09 :: idx = 301 , Total = 400 , Deleted = 300 , Problem = 0
# At 16:30:46 :: idx = 351 , Total = 400 , Deleted = 350 , Problem = 0
#
#
# Summary :: Total = 400 , Deleted = 400 , Problem = 0
# len(prob_files) = 0

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete

results_BOTH = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER)
print(f"\nresults for query with BOTH=\n{results_BOTH}")

results_FILES = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files')
print(f"\nresults for query with FILES=\n{results_FILES}")

results_FOLDERS = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'folders')
print(f"\nresults for query with FOLDERS=\n{results_FOLDERS}")
# Out:
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents
#
#
# results for query with BOTH=
# [{'name': 'subfolder333', 'id': '1GB2rl3avy8KUoxDN8B-y-THJWSHRmgVc'}, {'name': 'subfolder222', 'id': '1dHXCcWJekNCT40xY5SZYL_MZON6PABgb'}, {'name': 'subfolder111', 'id': '1BkFpEENiVuJ9Xq7jnp6Gc98bCEW0mJ2w'}, {'name': 'file_4.deletefile', 'id': '1-UUVxiNCWqZJZInnC8ZSW-a0i0IZFPkY'}, {'name': 'file_3.deletefile', 'id': '1-ZFvLpchsZ8XMLm_3cw1tFOlwNK5SPtk'}, {'name': 'file_2.deletefile', 'id': '1-axDYnX6l6hq60nGPpBy5afdgyE9kYuO'}, {'name': 'file_1.deletefile', 'id': '1-g1ZlBsvKIP_crCdfiQl6jm7GyEi6jux'}, {'name': 'file_0.deletefile', 'id': '1-TGlQjfW6seI3SgKV4VUqXKC43KH1Htj'}]
#
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
# results for query with FILES=
# [{'name': 'file_4.deletefile', 'id': '1-UUVxiNCWqZJZInnC8ZSW-a0i0IZFPkY'}, {'name': 'file_3.deletefile', 'id': '1-ZFvLpchsZ8XMLm_3cw1tFOlwNK5SPtk'}, {'name': 'file_2.deletefile', 'id': '1-axDYnX6l6hq60nGPpBy5afdgyE9kYuO'}, {'name': 'file_1.deletefile', 'id': '1-g1ZlBsvKIP_crCdfiQl6jm7GyEi6jux'}, {'name': 'file_0.deletefile', 'id': '1-TGlQjfW6seI3SgKV4VUqXKC43KH1Htj'}]
#
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents and mimeType='application/vnd.google-apps.folder'
#
#
# results for query with FOLDERS=
# [{'name': 'subfolder333', 'id': '1GB2rl3avy8KUoxDN8B-y-THJWSHRmgVc'}, {'name': 'subfolder222', 'id': '1dHXCcWJekNCT40xY5SZYL_MZON6PABgb'}, {'name': 'subfolder111', 'id': '1BkFpEENiVuJ9Xq7jnp6Gc98bCEW0mJ2w'}]

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete

results_FILES = retrieve_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files')
print(f"\nresults for query with FILES=\n{results_FILES}")
# Out:
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
# results for query with FILES=
# [{'name': 'file_4.deletefile', 'id': '1-UUVxiNCWqZJZInnC8ZSW-a0i0IZFPkY'}, {'name': 'file_3.deletefile', 'id': '1-ZFvLpchsZ8XMLm_3cw1tFOlwNK5SPtk'}, {'name': 'file_2.deletefile', 'id': '1-axDYnX6l6hq60nGPpBy5afdgyE9kYuO'}, {'name': 'file_1.deletefile', 'id': '1-g1ZlBsvKIP_crCdfiQl6jm7GyEi6jux'}, {'name': 'file_0.deletefile', 'id': '1-TGlQjfW6seI3SgKV4VUqXKC43KH1Htj'}]

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete
list_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER)
# Out:
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents
#
#
# Items for PAGE 1:
#
# Found folder/file: ('subfolder', '1BkFpEENiVuJ9Xq7jnp6Gc98bCEW0mJ2w')
# Found folder/file: ('file_4.deletefile', '1-UUVxiNCWqZJZInnC8ZSW-a0i0IZFPkY')
# Found folder/file: ('file_3.deletefile', '1-ZFvLpchsZ8XMLm_3cw1tFOlwNK5SPtk')
# Found folder/file: ('file_2.deletefile', '1-axDYnX6l6hq60nGPpBy5afdgyE9kYuO')
# Found folder/file: ('file_1.deletefile', '1-g1ZlBsvKIP_crCdfiQl6jm7GyEi6jux')
# Found folder/file: ('file_0.deletefile', '1-TGlQjfW6seI3SgKV4VUqXKC43KH1Htj')

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete
list_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'files')
# Out:
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents and mimeType != 'application/vnd.google-apps.folder'
#
#
# Items for PAGE 1:
#
# Found folder/file: ('file_4.deletefile', '1-UUVxiNCWqZJZInnC8ZSW-a0i0IZFPkY')
# Found folder/file: ('file_3.deletefile', '1-ZFvLpchsZ8XMLm_3cw1tFOlwNK5SPtk')
# Found folder/file: ('file_2.deletefile', '1-axDYnX6l6hq60nGPpBy5afdgyE9kYuO')
# Found folder/file: ('file_1.deletefile', '1-g1ZlBsvKIP_crCdfiQl6jm7GyEi6jux')
# Found folder/file: ('file_0.deletefile', '1-TGlQjfW6seI3SgKV4VUqXKC43KH1Htj')

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete
list_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'folders')
# Out:
# Query parameter built as:'1H9Be89645jTimwXPYPVMHeMQeqhEFjGi' in parents and mimeType='application/vnd.google-apps.folder'
#
#
# Items for PAGE 1:
#
# Found folder/file: ('subfolder', '1BkFpEENiVuJ9Xq7jnp6Gc98bCEW0mJ2w')

# %%
## list all the files AND folders in the target folder - default is both
## for only files    use   _files_or_folders='files'
## for only folders  use   _files_or_folders='folders'
GDRIVE_TARGET_FOLDER = '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi'  ## has 5 temp files to delete
list_items_in_gdrive_target_folder(service, GDRIVE_TARGET_FOLDER, _files_or_folders = 'wrongValue')
# Out:
# ERROR : invalid value for the '_files_or_folders' parameter. Expected one of these three options:
# both     OR    files    OR    folders
# Your query parater=
# wrongValue

# %%
## list all the folders only - WORKS  - but also seems to find from shared drives also
list_folders_in_gdrive_overall(service)
# Out:
# Folders for PAGE 1:
#
# Found folder: ('subfolder', '1BkFpEENiVuJ9Xq7jnp6Gc98bCEW0mJ2w')
# Found folder: ('coco_test2017_subset_95000_100000', '16QGxlnEKbGz9RcN3Yb_JrPGtaLISJSAY')
# Found folder: ('coco_test2017_subset_90000_95000', '1kjHtuE5WXGZGO3ZndR3g9rjxzXukKNm7')
# Found folder: ('coco_test2017_subset_85000_90000', '1qV5nlbjOwYhzqLnRb4W8_jbIL34i-EJb')
# Found folder: ('coco_test2017_subset_80000_85000', '1X7JxVvDZu9khxALLoAA0ELEkFjT9Z06C')
# Found folder: ('coco_test2017_subset_75000_80000', '1a8BKBcdLj0jGZyyUetvAzNJt4nk-DKwr')
# Found folder: ('coco_test2017_subset_70000_75000', '1-ipE7onHkLHM-LGeQdcqUABPzl281QuN')
# Found folder: ('coco_test2017_subset_65000_70000', '1-v5t6pTfRC9Y0EAsdJU2rMFZnWHAVt9P')
# Found folder: ('coco_test2017_subset_60000_65000', '10EVf2GlWh1c9gKMmcJAXI_z0_7KDSrUM')
# Found folder: ('coco_test2017_subset_55000_60000', '10Ghi7gP_GY21uVp15DxkJ3a4AgLWwyFr')
# Found folder: ('coco_test2017_subset_50000_55000', '1-zVNYILy7vinMW31RRzp8Dodi2kbQBPl')
# Found folder: ('coco_test2017_subset_45000_50000', '1-h_nEnDf9IAuwZEMlM_gI4iaEsjoqd44')
# Found folder: ('coco_test2017_subset_40000_45000', '1-OtyhCHzxNRwdxOG9-nu25jWK_aona3y')
# Found folder: ('coco_test2017_subset_35000_40000', '1-pVi5g0eeis1FvLPzz-K_KaYa_DuNF4N')
# Found folder: ('coco_test2017_subset_30000_35000', '1-ST34eZTk5-ymbFcCXxpUmzNyzI1pNMI')
# Found folder: ('coco_test2017_subset_25000_30000', '1-OGOHBj_I2ZKWixrG2HQgPchCkTof_ex')
# Found folder: ('coco_test2017_subset_20000_25000', '1-4IyQ5Qkc5fbXKXRQiNLOgHrktDuTmwr')
# Found folder: ('Weights', '1OsHFXIJu2UUOr9MLC2l9nhMXV5wbBMFS')
# Found folder: ('coco_test2017_subset_15000_20000', '1fpnwO_Mze-L5SCJ1oYAYu3qHXYq4Eg6W')
# Found folder: ('coco_test2017_subset_10000_15000', '1Lhhodk9ZWHcEyQy-7DfR-kowo8IWJoJD')
# Found folder: ('coco_test2017_subset_5000_10000', '1MhyM-v3jTryFEDx8G3wYuMWUCtf0FSPx')
# Found folder: ('coco_test2017_subset_0_5000', '1RhfDbyvFKoBp60w-6hmZVstVkGdAvVbo')
# Found folder: ('CocoTrain2017_1', '1FOxs0xhSEWcsfww3jbyd_uoRHQ4tH-ji')
# Found folder: ('Rishabh_DO_NOT_TOUCH_PLS_1', '1n9jymR4BvQ-qsMLLM8Hcqj5xjcMU4Su6')
# Found folder: ('COCO_train2017_118k', '1H76HF9yRRRdffGkzdKExaMWjMXV4YGcv')
# Found folder: ('coco_train2017_wget_1', '1B6H0GTD_LglDGiD9kBQbxNKp9kevP1bi')
# Found folder: ('Expose', '1Z_MAC9ypyK0fvJSGjt-kRBw11umcMyjY')
# Found folder: ('Data', '1evkBGhjVDq9BlMNMUvnXLiHQNok3TY9g')
# Found folder: ('credsFolder', '1AsTd9uwPYijC9vhLnbYtkEg7SSKOA7LA')
# Found folder: ('ThesisStoryGen', '1RmmzWkzJa6pnqu8G9KOGYlY8rR-3kQQL')
# Found folder: ('testdir', '1H9Be89645jTimwXPYPVMHeMQeqhEFjGi')
# Found folder: ('WordEmbeddings', '1fEMCZmr_AO7O9CLgsB-1TD9fJMMXDLni')
# Found folder: ('CocoVal2017_1', '1jpriQmU2GFFzoXf5jYDdbxEeaAC1MNdn')
# Found folder: ('ImgCapTraining', '1qojq2WXgeL6nGZkFm6n719eWr1i0rwAz')
# Found folder: ('val2017', '1--gwwytHdcL2p-bokbOm0fUPnsbHTLBp')
# Found folder: ('coco_val2017_wget_1', '146m-EEQtIUvIlLNNTSrM0ysNwjWc5CWg')
# Found folder: ('coco_annotations_trainval2017', '1jcPkdEkp4TQfc8IhNREAkW5DoekPFtlB')
# Found folder: ('NotesFolder', '1Gn9Lz4NfsF-bi0PrRwCa2mLG6EGuBs37')
# Found folder: ('Colab Notebooks', '16DKXkq7opJLK1einkbUuiDS3jXFGmpEw')
# Found folder: ('coco_test_2017_40k_images_op4neo_1_15k_20k', '1XMJ6LJ35t0N5ZaOiRLPymUbA6Imj9sJB')
# Found folder: ('coco_test_2017_40k_images_op4neo_1_5k_10k', '1mgzQQL3NKPrpaYAxwGtz38F4OrdMCeVj')
# Found folder: ('coco_test_2017_40k_images_op4neo_1_1_5k', '1mb_eJj0ZdfsioHR2JrSHhM9b6Ym99NIO')
# Found folder: ('saved_keras_model', '1loXKObyXpP9j9PzuYU3pvaZAT0kUkGhQ')
# Found folder: ('test2017', '1f056pFKuWBxSeGxqYHxP1bDbwGvQYFmx')
# Found folder: ('coco_test2017_wget_1', '1ewB-p4h8JMQIug1vv6bx3sSIhssIX642')
# Found folder: ('wavs', '12dmbA9MNbkjgr_T5PAeBItgDjJS8iAXY')
# Found folder: ('audio', '1DaKDqZ8tZvu4cklobO7pAtLJ-JZebJf8')
# Found folder: ('Papers', '13K2bY3cEc4xEa-ksa-m6zETMN_nBcAUo')
# Found folder: ('pku-autonomous-driving', '1-Rv1xiIdW6D1U9Q4UCyasTUnu0bhiuPo')
# Found folder: ('FINAL_report_ppt', '1N9n1TGQu4voBxETLM84zNbhd9o4v996g')
# Found folder: ('CaseStudy2-AutonomousDriving', '16ZnEUaqXftv2cMIvaYnLluEVsa4vnqfC')
# Found folder: ('rohit', '1VvviYIXxBGvzVKKzj6t7zqHc04G_6Ctv')
# Found folder: ('Report', '12RhOA9Npqa90EOuAWewxvDsLKJnw-0hY')
# Found folder: ('papers', '15vojYSYa0APdIjiyp2DQ3IjYypRgvzsm')
# Found folder: ('data', '16siEBN_9LEbrPyK78sC_xL9cS5zi0W2O')
# Found folder: ('newDataDoNotUse', '1Qf9-85SjdONOt8H19QUzIZy9mjyWi-G5')
# Found folder: ('code', '1GkUxC0JmHAcV5knXReGgEXK4h98ftfHq')
# Found folder: ('pickle_files', '1kQY6zjM2TPPQqzy1NT3nIn-uGPDAe7EC')
# Found folder: ('demo', '1VR2I7cJoBNrLTKcyXEMLGKqm13CjEHn2')
# Found folder: ('demoDataCollection', '172vxy9cEczO7TqgfRnKurnUNCbR3qJIo')
# Found folder: ('bigger', '1Z3mS25PCxcW1zw8ZJZBE0hXoOx2JP4c5')
# Found folder: ('tableau', '1QIzcu2byGwBldrmQ8fey0-I2QN83yWY8')
# Found folder: ('FakeNews', '1v7FI9pvO6thol9quNdjIvE7MG2Uatpix')
# Found folder: ('AllFeaturesCombined', '1KG7wqc1yPmTPBQEZitKzrzsvrz_uq2zO')
# Found folder: ('FinalMorphologicalFeaturesDataCombined', '1gash3HHSLxELYAMOzsVtZmiT5ce2qoE5')
# Found folder: ('FinalTwitterFeaturesDataCombined', '1LUVEA2lGY17urKEZ1BO2l82g6zH1Kn9O')
# Found folder: ('WRONGFinalTwitterFeaturesDataCombined', '1fGY3RdBV3O31dcGyM82bb0m4ocAdIiZ6')
# Found folder: ('FinalLIWCFeaturesDataCombined', '1vEYMiAlyGzlcgHX9y1lSVCR8ysBfMU5g')
# Found folder: ('FinalReadabilityFeaturesDataCombined', '1e4JZyo8GH93t_ee8mSQVemnW9IwN_f3o')
# Found folder: ('Shekhar', '10NQCKaZGOJZD0wWSUcmZedJkcX8n7L9H')
# Found folder: ('Sanika', '1UiRnvLkxc-ltXo2JoHWxODwwSI2y3eka')
# Found folder: ('Rishabh', '1lAWJGOzMRJ6blEAsfLZVGCSYs6N9xeTY')
# Found folder: ('Sid', '1mFOgY6eawvEFzwjo_3ST65TIoAaCuEV0')
# Found folder: ('Manmeet', '17_-BTVz8CI-He4MdTsPB2IfKaoaUcbRg')
# Found folder: ('Rohit', '1wHJ87TnlB7lMForX4_EnEI3DAdjNrk4K')
# Found folder: ('ContentFeaturesParts', '1dmTYf02LeZmpw6MLVI77tFLpZOzRNrym')
# Found folder: ('FinalData', '1c4LrJQsrqjj3sJ7yU6CJI6Y2Lf0jNbhN')
# Found folder: ('toProcess', '1JCY6G4aoegUwcMwnKmsTye1Py54k3p8J')
# Found folder: ('toProcess', '1KPFQRXeS83FcNVcdQIYoQ2uvZhojxO2F')
# Found folder: ('toProcess', '1SSOhzNXeFBaZB0oNRPSbBlREx-2DSrbl')
# Found folder: ('toProcess', '1Vnbj4gMpaaR7Q3h3C8ELAEFwJHGejYS8')
# Found folder: ('rishabh', '1e-sGaQqdOIWOicfvxI_OzbfLCM37pMa6')
# Found folder: ('shekhar', '1Jk3T3Bic-mzy4iJ9wKbTxL96ea01Ugba')
# Found folder: ('sid', '1zLYO86-U2Z_0yn_0iMIyKHLC3A3QKmYP')
# Found folder: ('rohit', '1C8ox18uVOgRRVcHSAa8Y6ciZAQMl6Z4X')
# Found folder: ('twitter', '1Rh33SiFNJUZcY2J-Ych04z5wE4LYXGYK')
# Found folder: ('data', '1fj-C0JOiVQXJLrhvLSCyTA_E0hEhsAVN')
# Found folder: ('Report and PPT', '1MQQ0HAGzdewCdtk-nyFFTF8sCbLzcjcP')
# Found folder: ('Expose', '18S8Blq8XrrfLBsicuDMnryYd9BQcE1HF')
# Found folder: ('Images', '1mhmUwHFVNXiQ02Ul1bgRYg-ubYqc5NiS')
# Found folder: ('IEEE', '12Bzi0nID1WMFFPVFX_2w9TTmUitxhFS3')
# Found folder: ('Research Paper', '1I2LovvT5liDshaup1GBhKyfLe1ZUuIlK')
